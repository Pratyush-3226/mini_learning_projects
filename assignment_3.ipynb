# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyush-3226/mini_learning_projects/blob/main/assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Titanic.csv")

# %%
plt.plot(df["Age"])
plt.xlabel("Serial Number")
plt.ylabel("age")
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(x="Sex",data=df)
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Male vs Female")
plt.show()

# %%
sns.countplot(x="Pclass",data=df)
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Passenger Class Distribution")
plt.show()

# %%
plt.boxplot(df["Fare"])
plt.show()

# %%
plt.scatter(df["Fare"],df["Age"])
plt.xlabel("Fare")
plt.ylabel("Age")
plt.title("Fare vs Age")
plt.show()

# %%
sns.heatmap(numeric_df.corr(), annot=True, cmap="cool")
plt.title("Heatmap for Numeric Columns")
plt.show()

# %%
plt.savefig("heatmap_name.png")

# %%
plt.savefig("scatter_name.png")

# %%
plt.savefig("boxplot_name.png")

# %%
plt.savefig("countplot_name.png")

# %%
plt.savefig("countplot_name.png")

# %%
plt.savefig("plot_name.png")
